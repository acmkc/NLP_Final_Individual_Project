# %%
import pandas as pd

# %%
import numpy as np

# %%
url = "https://raw.githubusercontent.com/acmkc/NLP_Final_Individual_Project_Group4/main/Marseille%20NOx%20emission.csv?token=GHSAT0AAAAAACELFH6BVXTIQA33IOC3DQ5QZK77FZQ"
f = pd.read_csv(url)

# %%
f
# Out:
#      Year           Activity               Energy      Value Unit
# 0    2010        Agriculture       Aucune énergie      217.6   kg
# 1    2010        Agriculture          Gaz Naturel      281.1   kg
# 2    2010        Agriculture  Produits pétroliers      851.8   kg
# 3    2010         Biogénique       Aucune énergie     2658.2   kg
# 4    2010        Ferroviaire  Produits pétroliers    17590.6   kg
# ..    ...                ...                  ...        ...  ...
# 277  2021          Tertiaire   Bois-énergie (EnR)     1326.1   kg
# 278  2021          Tertiaire          Gaz Naturel   196025.3   kg
# 279  2021          Tertiaire  Produits pétroliers    39254.9   kg
# 280  2021  Transport Routier          Gaz Naturel    14751.2   kg
# 281  2021  Transport Routier  Produits pétroliers  1679772.9   kg
#
# [282 rows x 5 columns]
